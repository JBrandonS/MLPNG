# %%
import sys
import numpy as np

sys.path.append('scripts')
from utils import *
from config import SimConfig

# %%
data = load_data('data/unlensed/128_nn_T_10000x10_fnl-1000-1000.hdf5', ['fnls', 'estimates', 'fisher'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /users/stevensonb/Research/MLPNG/ksw_viwer.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bm3.smu.edu/users/stevensonb/Research/MLPNG/ksw_viwer.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> data = load_data('data/unlensed/128_nn_T_10000x10_fnl-1000-1000.hdf5', ['fnls', 'estimates', 'fisher'])
#
# File ~/Research/MLPNG/scripts/utils.py:56, in load_data(data_file, keys, start_index, end_index, verbose)
#      52     keys = [keys]
#      54 data = {}
# ---> 56 with h5py.File(data_file, "r", swmr=True, locking=False) as hdf:
#      57     for key in keys:
#      58         if verbose:
#
# ...

# %%
data['fisher']
# Out:
# array([3078590.26983073])

# %%
fnls = data['fnls']

errors = ( data['estimates'] - fnls ) / fnls
errors
# Out:
# array([-1.00000784, -1.00002993, -0.99998643, ..., -1.00004004,
#        -0.99999564, -0.99999723])

# %%
import matplotlib.pyplot as plt

x = np.arange(len(data['fnls']))

plt.scatter(np.arange(len(data['fnls'])), data['fnls'], label='fnls')
plt.plot(data['estimates'], label='estimates', c="red")
plt.legend()

plt.show()

# %%
np.max(data['estimates'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /users/stevensonb/Research/MLPNG/ksw_viwer.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bm3.smu.edu/users/stevensonb/Research/MLPNG/ksw_viwer.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> np.max(data['estimates'])
#
# NameError: name 'np' is not defined
