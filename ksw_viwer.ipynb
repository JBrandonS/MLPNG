# %%
import sys
import numpy as np

sys.path.append('scripts')
from utils import *
from config import SimConfig

# %%
data = load_data('data/unlensed/2048_nn_T_10000x10_fnl-1000-1000.hdf5', ['fnls', 'estimates', 'fisher'])

# %%
data['fisher']

# %%
fnls = data['fnls']

errors = ( data['estimates'] - fnls ) / fnls
errors

# %%
import matplotlib.pyplot as plt

x = np.arange(len(data['fnls']))

plt.scatter(np.arange(len(data['fnls'])), data['fnls'], label='fnls')
plt.plot(data['estimates'], label='estimates', c="red")
plt.legend()

plt.show()
